# %% [markdown]
# # Supermarket recommendation system Code

# %%
import csv
import ast
import numpy as np
from itertools import combinations
from operator import itemgetter

# %% [markdown]
# ### Supermarket data Preprocessing

# %%
trans = [] #all transactions
with open("supermarket.csv") as csv_file:
    read_file = csv.reader(csv_file, delimiter = ',')
    for row in read_file:
        row.pop(-1)
        trans.append(row)
all_items = [j for i in trans for j in i] #all items in all transactions
np_items = np.array(all_items)
unique = list(np.unique(np_items))
max_row = max(len(x) for x in trans)
#print(unique)

# %% [markdown]
# ### To get Frequency for k=1 itemset

# %%
def itemfreq(data):
    unique, counts = np.unique(data, return_counts=True)
    freq = dict(zip(unique, counts))
    return freq

# %% [markdown]
# ### Apriori function to get frequent itemsets

# %%
def apriori_func(all_items, trans, minsup):

    can_set = []
    pruned_set = []
    item_dict = {}
    ini_freq = itemfreq(all_items)
    sup_count = {}
    sup_count[str(1)]= {k:v for k,v in ini_freq.items()}
    super_dict = {}
    super_dict[str(1)] = {k:v / len(trans) for k,v in ini_freq.items()}
    sub_a = [[b] for b in super_dict['1'].keys()]
    item_set = [sub_a]
    sup_check = {}
    sup_counter = {}

    for k in range(1, 48):
        for count, i in enumerate(sub_a):
            if count >= len(sub_a):
                    break
            for count_b, j in enumerate(sub_a, start=count+1):
                if count_b >= len(sub_a):
                    break
                p = sub_a[count]
                p_copy = p.copy()
                q = sub_a[count_b]
                if p[0:-1] == q[0:-1]:
                    p_copy.append(q[-1])
                    can_set.append(p_copy)

        for subset in can_set:
            check = combinations(subset, k)
            lst = [list(s) for s in check]
            for indx, l in enumerate(lst, start=0):
                if l in item_set[k-1]:
                    if indx == k:
                        pruned_set.append(subset) ### creates candidate set

        for m in pruned_set:
            for n in trans:
                s = str(m)
                if all(stuff in n for stuff in m):
                    item_dict[s] = item_dict.get(s, 0) + 1  ###does support count for itemset
                else:
                    item_dict[s] = item_dict.get(s, 0)
                    
        #sup_count[str(k+1)].append(item_dict)
        
        for key, val in item_dict.items():
            support = val / len(trans) ###calculates support and applies constraint
            if support >= minsup:
                sup_check[key] = round(support, 3)
                sup_counter[key] = val
                
        if bool(sup_check) == False:
            break
        sup_count[str(k+1)] = sup_counter
        sup_set = [ast.literal_eval(v) for v in sup_check.keys()]
        super_dict[str(k+1)] = sup_check
        item_dict = {}
        item_set.insert(k, sup_set)
        sub_a = item_set[k]
        can_set = []
        pruned_set = []
        sup_check = {}
        sup_counter = {}
    return super_dict, sup_count ###returns support dict and support count dict

# %% [markdown]
# ### Function to generate rules and calculate confidence/lift as well as sort the output

# %%
def association_func(frequent_sets, freq_sup, minconf, minlift):
    denom_lst = []
    conf_dict = {}
    lift_dict = {}
    final_dict = {}
    for k in range (2, len(frequent_sets) + 1):
        for keyy, value in frequent_sets[str(k)].items():
            key = ast.literal_eval(keyy)
            for i in range(1, len(key)):
                denom = combinations(key, i)
                denom_lst = [list(x) for x in denom]
                for j in denom_lst:
                    numer_lst = [y for y in key if y not in j]
                    conf_val = (value / frequent_sets.get(str(len(numer_lst))).get(str(numer_lst)))
                    lift_val = (conf_val / freq_sup.get(str(len(j))).get(str(j)))
                    b_val = freq_sup.get(str(len(j))).get(str(j))
                    if (conf_val >=  minconf) and (lift_val >= minlift):
                        val_lst = [conf_val, round(lift_val, 3)]
                        final_dict[str(numer_lst) + '-->' + str(j)] = { "rule": str(numer_lst) + '-->' + str(j), "length": len(key), 'lift': round(lift_val, 3), 'confidence': round(conf_val, 3), 'support': freq_sup.get(str(len(key))).get(keyy)}     
    final_lst = list(final_dict.values())
    ###sort by length, lift, conf, sup respectively then descending order
    sorted_final = sorted(final_lst, key=itemgetter('length', 'lift', 'confidence', 'support'), reverse=True) 
    return sorted_final

# %% [markdown]
# ### Generate frequent itemsets (by running Apriori Function on datasets)

# %%
def apriori_run(all_items, trans, minsup):
    sup, sup_count = apriori_func(all_items, trans, minsup)
    sup['1'] = {k.replace(k, str([k])): v for k, v in sup.get('1').items()} 
    sup_count['1'] = {k.replace(k, str([k])): v for k, v in sup_count.get('1').items()} 
    
    return sup, sup_count

# %%
sup, sup_count = apriori_run(all_items, trans, 0.15) 
###Takes three parameters all_items (which is a list of every item in dataset), 
###trans(which is each row in dataset) and minsup
###returns sup (dict of support of each itemset) and sup_count (dict of support count of each itemsset)

# %% [markdown]
# ### Generate Rules, calculations and sort

# %%
def rules_run(sup, sup_count, minconf, minlift):
    total_sets = sum([len(t) for t in sup.values()]) #number of frequent itemsets
    rules = association_func(sup_count, sup, minconf, minlift) #Takes four parameters support count, support, minconf, minlift respectively
    rule_count = 0
    for r in rules:
        rule_count += 1
    return total_sets, rules, rule_count

# %%
#Takes four parameters support, support count, minconf, minlift respectively
total_sets, rules, rule_count = rules_run(sup, sup_count, 0.80, 0)

# %%
print('number of frequents itemset:', total_sets)
print('number of rules:', rule_count)
print('Itemsets:')   
for s in sup.values():
    for x, y in s.items():
        print(x, y)  ###prints itemsets with their support
print(' ')
print('Rules:')
for r in rules:
    print(r)
# Out:
# number of frequents itemset: 1838
# number of rules: 737
# Itemsets:
# ['750ml red imp'] 0.020963907499459693
# ['750ml red nz'] 0.019667170953101363
# ['750ml white imp'] 0.02139615301491247
# ['750ml white nz'] 0.060730494921115194
# ['baby needs'] 0.13377998703263452
# ['bake off products'] 0.12146098984223039
# ['baking needs'] 0.6040631078452561
# ['beef'] 0.37583747568618975
# ['beverages hot'] 0.09833585476550681
# ['biscuits'] 0.5629997838772423
# ['bread and cake'] 0.719688783228874
# ['breakfast food'] 0.40242057488653554
# ['brushware'] 0.023557380592176356
# ['canned fish-meat'] 0.20337151502053166
# ['canned fruit'] 0.27728549816295656
# ['canned vegetables'] 0.3408255889345148
# ['casks red wine'] 0.011022260644045817
# ['casks white wine'] 0.03760535984439162
# ['cheese'] 0.40609466176788417
# ['chickens'] 0.0045385779122541605
# ['cigarette cartons'] 0.007996542035876377
# ['cigs-tobacco pkts'] 0.15106980765074562
# ['cleaners-polishers'] 0.2727469202507024
# ['coffee'] 0.2364382969526691
# ['cold-meats'] 0.14523449319213314
# ['condiments'] 0.0568402852820402
# ['confectionary'] 0.3652474605575967
# ['cooking oils'] 0.10330667819321375
# ['cough-cold-pain'] 0.07823643829695266
# ['dairy foods'] 0.36070888264534257
# ['deli gourmet'] 0.04495353360708883
# ['delicatessen misc'] 0.023341257834449968
# ['dental needs'] 0.22995461422087746
# ['deod-disinfectant'] 0.08191052517830127
# ['deodorants-soap'] 0.2329803328290469
# ['department1'] 0.22628052733952886
# ['department11'] 0.001080613788631943
# ['department122'] 0.24032850659174412
# ['department123'] 0.008428787551329154
# ['department124'] 0.020531661984006917
# ['department130'] 0.07110438729198185
# ['department137'] 0.40069159282472444
# ['department141'] 0.002161227577263886
# ['department193'] 0.002161227577263886
# ['department2'] 0.028312081262156907
# ['department210'] 0.04127944672574022
# ['department211'] 0.04473741084936244
# ['department212'] 0.008212664793602767
# ['department213'] 0.004754700669980549
# ['department3'] 0.01945104819537497
# ['department4'] 0.018154311649016642
# ['department5'] 0.037821482602118005
# ['department6'] 0.0004322455154527772
# ['department7'] 0.014480224767668035
# ['department79'] 0.08428787551329155
# ['department80'] 0.03371515020531662
# ['department9'] 0.017722066133563863
# ['dishcloths-scour'] 0.07823643829695266
# ['dried vegetables'] 0.006267559974065269
# ['electrical'] 0.11108709747136374
# ['frozen foods'] 0.5872055327425978
# ['fruit'] 0.640155608385563
# ['fruit drinks'] 0.006915928247244435
# ['fuels-garden aids'] 0.03652474605575967
# ['gourmet meat'] 0.0004322455154527772
# ['grocery misc'] 0.03846985087529717
# ['haberdashery'] 0.009725524097687486
# ['haircare'] 0.18283985303652475
# ['health food other'] 0.07369786038469851
# ['health&beauty misc'] 0.01685757510265831
# ['hogget'] 0.020531661984006917
# ['imported cheese'] 0.05035660255024854
# ['insecticides'] 0.10481953749729847
# ['jams-spreads'] 0.2762048843743246
# ['juice-sat-cord-ms'] 0.532310352280095
# ['kitchen'] 0.07045601901880268
# ['lamb'] 0.1022260644045818
# ['laundry needs'] 0.33779987032634534
# ['lotions-creams'] 0.06354009077155824
# ['manchester'] 0.03738923708666522
# ['margarine'] 0.4944888696779771
# ['meat misc'] 0.028312081262156907
# ['medicines'] 0.04408904257618327
# ['mens toiletries'] 0.05597579425113464
# ['milk-cream'] 0.635184784957856
# ['mutton'] 0.004970823427706938
# ['non host support'] 0.01880267992219581
# ['offal'] 0.02139615301491247
# ['pantyhose'] 0.009293278582234709
# ['party snack foods'] 0.5035660255024854
# ['pet food'] 0.11519342986816512
# ['pet foods'] 0.4035011886751675
# ['pkt-canned soup'] 0.09790360925005404
# ['plants'] 0.006267559974065269
# ['plasticware'] 0.014912470283120812
# ['pork'] 0.07456235141560406
# ['port and sherry'] 0.005403068943159715
# ['potatoes'] 0.15863410417116922
# ['poultry'] 0.15971471795980116
# ['prepared meals'] 0.2746920250702399
# ['preserving needs'] 0.012102874432677761
# ['produce misc'] 0.052517830127512426
# ['puddings-deserts'] 0.1703047330883942
# ['razor blades'] 0.04322455154527772
# ['salads'] 0.0012967365463583316
# ['sanitary pads'] 0.08990706721417766
# ['sauces-gravy-pkle'] 0.4756861897557813
# ['small goods'] 0.24119299762264967
# ['small goods2'] 0.2079100929327858
# ['soft drinks'] 0.40803976658742164
# ['sparkling imp'] 0.004970823427706938
# ['sparkling nz'] 0.027879835746704128
# ['spices'] 0.0775880700237735
# ['stationary'] 0.3148908580073482
# ['tea'] 0.19364599092284418
# ['tissues-paper prd'] 0.4856278366111952
# ['trim lamb'] 0.009941646855413875
# ['trim pork'] 0.027447590231251352
# ['variety misc'] 0.06894315971471796
# ['veal'] 0.019667170953101363
# ['vegetables'] 0.6399394856278366
# ['wrapping'] 0.28874000432245517
# ['baking needs', 'beef'] 0.25
# ['baking needs', 'biscuits'] 0.381
# ['baking needs', 'bread and cake'] 0.474
# ['baking needs', 'breakfast food'] 0.289
# ['baking needs', 'canned fruit'] 0.196
# ['baking needs', 'canned vegetables'] 0.246
# ['baking needs', 'cheese'] 0.284
# ['baking needs', 'cleaners-polishers'] 0.195
# ['baking needs', 'coffee'] 0.171
# ['baking needs', 'confectionary'] 0.237
# ['baking needs', 'dairy foods'] 0.243
# ['baking needs', 'dental needs'] 0.165
# ['baking needs', 'deodorants-soap'] 0.164
# ['baking needs', 'department122'] 0.154
# ['baking needs', 'department137'] 0.262
# ['baking needs', 'frozen foods'] 0.397
# ['baking needs', 'fruit'] 0.411
# ['baking needs', 'jams-spreads'] 0.202
# ['baking needs', 'juice-sat-cord-ms'] 0.35
# ['baking needs', 'laundry needs'] 0.237
# ['baking needs', 'margarine'] 0.356
# ['baking needs', 'milk-cream'] 0.412
# ['baking needs', 'party snack foods'] 0.331
# ['baking needs', 'pet foods'] 0.272
# ['baking needs', 'prepared meals'] 0.194
# ['baking needs', 'sauces-gravy-pkle'] 0.329
# ['baking needs', 'small goods'] 0.168
# ['baking needs', 'soft drinks'] 0.259
# ['baking needs', 'stationary'] 0.199
# ['baking needs', 'tissues-paper prd'] 0.34
# ['baking needs', 'vegetables'] 0.421
# ['baking needs', 'wrapping'] 0.211
# ['beef', 'biscuits'] 0.23
# ['beef', 'bread and cake'] 0.297
# ['beef', 'breakfast food'] 0.171
# ['beef', 'canned vegetables'] 0.153
# ['beef', 'cheese'] 0.175
# ['beef', 'department137'] 0.165
# ['beef', 'frozen foods'] 0.258
# ['beef', 'fruit'] 0.256
# ['beef', 'juice-sat-cord-ms'] 0.211
# ['beef', 'margarine'] 0.213
# ['beef', 'milk-cream'] 0.252
# ['beef', 'party snack foods'] 0.198
# ['beef', 'pet foods'] 0.187
# ['beef', 'sauces-gravy-pkle'] 0.205
# ['beef', 'soft drinks'] 0.158
# ['beef', 'tissues-paper prd'] 0.211
# ['beef', 'vegetables'] 0.278
# ['biscuits', 'bread and cake'] 0.45
# ['biscuits', 'breakfast food'] 0.267
# ['biscuits', 'canned fruit'] 0.191
# ['biscuits', 'canned vegetables'] 0.237
# ['biscuits', 'cheese'] 0.265
# ['biscuits', 'cleaners-polishers'] 0.177
# ['biscuits', 'coffee'] 0.155
# ['biscuits', 'confectionary'] 0.245
# ['biscuits', 'dairy foods'] 0.238
# ['biscuits', 'dental needs'] 0.156
# ['biscuits', 'deodorants-soap'] 0.153
# ['biscuits', 'department122'] 0.152
# ['biscuits', 'department137'] 0.25
# ['biscuits', 'frozen foods'] 0.391
# ['biscuits', 'fruit'] 0.397
# ['biscuits', 'jams-spreads'] 0.192
# ['biscuits', 'juice-sat-cord-ms'] 0.333
# ['biscuits', 'laundry needs'] 0.221
# ['biscuits', 'margarine'] 0.323
# ['biscuits', 'milk-cream'] 0.382
# ['biscuits', 'party snack foods'] 0.344
# ['biscuits', 'pet foods'] 0.256
# ['biscuits', 'prepared meals'] 0.182
# ['biscuits', 'sauces-gravy-pkle'] 0.304
# ['biscuits', 'small goods'] 0.161
# ['biscuits', 'soft drinks'] 0.258
# ['biscuits', 'stationary'] 0.194
# ['biscuits', 'tissues-paper prd'] 0.314
# ['biscuits', 'vegetables'] 0.381
# ['biscuits', 'wrapping'] 0.197
# ['bread and cake', 'breakfast food'] 0.311
# ['bread and cake', 'canned fish-meat'] 0.163
# ['bread and cake', 'canned fruit'] 0.225
# ['bread and cake', 'canned vegetables'] 0.271
# ['bread and cake', 'cheese'] 0.322
# ['bread and cake', 'cleaners-polishers'] 0.212
# ['bread and cake', 'coffee'] 0.181
# ['bread and cake', 'confectionary'] 0.278
# ['bread and cake', 'dairy foods'] 0.285
# ['bread and cake', 'dental needs'] 0.179
# ['bread and cake', 'deodorants-soap'] 0.182
# ['bread and cake', 'department1'] 0.172
# ['bread and cake', 'department122'] 0.18
# ['bread and cake', 'department137'] 0.317
# ['bread and cake', 'frozen foods'] 0.46
# ['bread and cake', 'fruit'] 0.502
# ['bread and cake', 'jams-spreads'] 0.222
# ['bread and cake', 'juice-sat-cord-ms'] 0.404
# ['bread and cake', 'laundry needs'] 0.267
# ['bread and cake', 'margarine'] 0.396
# ['bread and cake', 'milk-cream'] 0.505
# ['bread and cake', 'party snack foods'] 0.391
# ['bread and cake', 'pet foods'] 0.322
# ['bread and cake', 'prepared meals'] 0.219
# ['bread and cake', 'sauces-gravy-pkle'] 0.37
# ['bread and cake', 'small goods'] 0.201
# ['bread and cake', 'small goods2'] 0.163
# ['bread and cake', 'soft drinks'] 0.309
# ['bread and cake', 'stationary'] 0.243
# ['bread and cake', 'tea'] 0.153
# ['bread and cake', 'tissues-paper prd'] 0.384
# ['bread and cake', 'vegetables'] 0.497
# ['bread and cake', 'wrapping'] 0.227
# ['breakfast food', 'canned vegetables'] 0.171
# ['breakfast food', 'cheese'] 0.197
# ['breakfast food', 'confectionary'] 0.154
# ['breakfast food', 'dairy foods'] 0.172
# ['breakfast food', 'department137'] 0.18
# ['breakfast food', 'frozen foods'] 0.273
# ['breakfast food', 'fruit'] 0.282
# ['breakfast food', 'juice-sat-cord-ms'] 0.251
# ['breakfast food', 'laundry needs'] 0.173
# ['breakfast food', 'margarine'] 0.238
# ['breakfast food', 'milk-cream'] 0.272
# ['breakfast food', 'party snack foods'] 0.236
# ['breakfast food', 'pet foods'] 0.187
# ['breakfast food', 'prepared meals'] 0.154
# ['breakfast food', 'sauces-gravy-pkle'] 0.223
# ['breakfast food', 'soft drinks'] 0.173
# ['breakfast food', 'tissues-paper prd'] 0.237
# ['breakfast food', 'vegetables'] 0.276
# ['canned fruit', 'frozen foods'] 0.199
# ['canned fruit', 'fruit'] 0.202
# ['canned fruit', 'juice-sat-cord-ms'] 0.169
# ['canned fruit', 'margarine'] 0.169
# ['canned fruit', 'milk-cream'] 0.191
# ['canned fruit', 'party snack foods'] 0.156
# ['canned fruit', 'sauces-gravy-pkle'] 0.159
# ['canned fruit', 'tissues-paper prd'] 0.159
# ['canned fruit', 'vegetables'] 0.196
# ['canned vegetables', 'cheese'] 0.177
# ['canned vegetables', 'department137'] 0.153
# ['canned vegetables', 'frozen foods'] 0.241
# ['canned vegetables', 'fruit'] 0.243
# ['canned vegetables', 'juice-sat-cord-ms'] 0.209
# ['canned vegetables', 'margarine'] 0.213
# ['canned vegetables', 'milk-cream'] 0.231
# ['canned vegetables', 'party snack foods'] 0.198
# ['canned vegetables', 'pet foods'] 0.17
# ['canned vegetables', 'sauces-gravy-pkle'] 0.211
# ['canned vegetables', 'tissues-paper prd'] 0.209
# ['canned vegetables', 'vegetables'] 0.25
# ['cheese', 'confectionary'] 0.162
# ['cheese', 'dairy foods'] 0.179
# ['cheese', 'department137'] 0.189
# ['cheese', 'frozen foods'] 0.268
# ['cheese', 'fruit'] 0.284
# ['cheese', 'juice-sat-cord-ms'] 0.248
# ['cheese', 'laundry needs'] 0.166
# ['cheese', 'margarine'] 0.253
# ['cheese', 'milk-cream'] 0.279
# ['cheese', 'party snack foods'] 0.24
# ['cheese', 'pet foods'] 0.187
# ['cheese', 'sauces-gravy-pkle'] 0.234
# ['cheese', 'soft drinks'] 0.179
# ['cheese', 'tissues-paper prd'] 0.239
# ['cheese', 'vegetables'] 0.29
# ['cleaners-polishers', 'frozen foods'] 0.182
# ['cleaners-polishers', 'fruit'] 0.183
# ['cleaners-polishers', 'juice-sat-cord-ms'] 0.162
# ['cleaners-polishers', 'margarine'] 0.164
# ['cleaners-polishers', 'milk-cream'] 0.182
# ['cleaners-polishers', 'sauces-gravy-pkle'] 0.155
# ['cleaners-polishers', 'tissues-paper prd'] 0.17
# ['cleaners-polishers', 'vegetables'] 0.19
# ['coffee', 'frozen foods'] 0.153
# ['coffee', 'fruit'] 0.154
# ['coffee', 'milk-cream'] 0.159
# ['coffee', 'vegetables'] 0.161
# ['confectionary', 'department137'] 0.159
# ['confectionary', 'frozen foods'] 0.234
# ['confectionary', 'fruit'] 0.249
# ['confectionary', 'juice-sat-cord-ms'] 0.216
# ['confectionary', 'margarine'] 0.197
# ['confectionary', 'milk-cream'] 0.249
# ['confectionary', 'party snack foods'] 0.221
# ['confectionary', 'pet foods'] 0.162
# ['confectionary', 'sauces-gravy-pkle'] 0.186
# ['confectionary', 'soft drinks'] 0.179
# ['confectionary', 'tissues-paper prd'] 0.189
# ['confectionary', 'vegetables'] 0.238
# ['dairy foods', 'department137'] 0.163
# ['dairy foods', 'frozen foods'] 0.239
# ['dairy foods', 'fruit'] 0.261
# ['dairy foods', 'juice-sat-cord-ms'] 0.218
# ['dairy foods', 'margarine'] 0.203
# ['dairy foods', 'milk-cream'] 0.247
# ['dairy foods', 'party snack foods'] 0.225
# ['dairy foods', 'pet foods'] 0.169
# ['dairy foods', 'sauces-gravy-pkle'] 0.199
# ['dairy foods', 'soft drinks'] 0.159
# ['dairy foods', 'tissues-paper prd'] 0.197
# ['dairy foods', 'vegetables'] 0.254
# ['dental needs', 'frozen foods'] 0.16
# ['dental needs', 'fruit'] 0.154
# ['dental needs', 'vegetables'] 0.154
# ['deodorants-soap', 'frozen foods'] 0.159
# ['deodorants-soap', 'fruit'] 0.159
# ['deodorants-soap', 'milk-cream'] 0.154
# ['deodorants-soap', 'tissues-paper prd'] 0.154
# ['deodorants-soap', 'vegetables'] 0.164
# ['department1', 'fruit'] 0.158
# ['department1', 'milk-cream'] 0.151
# ['department122', 'fruit'] 0.169
# ['department122', 'milk-cream'] 0.166
# ['department122', 'vegetables'] 0.168
# ['department137', 'frozen foods'] 0.257
# ['department137', 'fruit'] 0.275
# ['department137', 'juice-sat-cord-ms'] 0.227
# ['department137', 'laundry needs'] 0.154
# ['department137', 'margarine'] 0.22
# ['department137', 'milk-cream'] 0.276
# ['department137', 'party snack foods'] 0.227
# ['department137', 'pet foods'] 0.181
# ['department137', 'sauces-gravy-pkle'] 0.208
# ['department137', 'soft drinks'] 0.185
# ['department137', 'tissues-paper prd'] 0.209
# ['department137', 'vegetables'] 0.28
# ['frozen foods', 'fruit'] 0.402
# ['frozen foods', 'jams-spreads'] 0.188
# ['frozen foods', 'juice-sat-cord-ms'] 0.35
# ['frozen foods', 'laundry needs'] 0.23
# ['frozen foods', 'margarine'] 0.331
# ['frozen foods', 'milk-cream'] 0.395
# ['frozen foods', 'party snack foods'] 0.342
# ['frozen foods', 'pet foods'] 0.268
# ['frozen foods', 'prepared meals'] 0.201
# ['frozen foods', 'sauces-gravy-pkle'] 0.324
# ['frozen foods', 'small goods'] 0.165
# ['frozen foods', 'soft drinks'] 0.273
# ['frozen foods', 'stationary'] 0.193
# ['frozen foods', 'tissues-paper prd'] 0.325
# ['frozen foods', 'vegetables'] 0.407
# ['frozen foods', 'wrapping'] 0.199
# ['fruit', 'jams-spreads'] 0.193
# ['fruit', 'juice-sat-cord-ms'] 0.361
# ['fruit', 'laundry needs'] 0.232
# ['fruit', 'margarine'] 0.332
# ['fruit', 'milk-cream'] 0.44
# ['fruit', 'party snack foods'] 0.344
# ['fruit', 'pet foods'] 0.281
# ['fruit', 'prepared meals'] 0.185
# ['fruit', 'sauces-gravy-pkle'] 0.322
# ['fruit', 'small goods'] 0.171
# ['fruit', 'soft drinks'] 0.274
# ['fruit', 'stationary'] 0.217
# ['fruit', 'tissues-paper prd'] 0.339
# ['fruit', 'vegetables'] 0.477
# ['fruit', 'wrapping'] 0.201
# ['jams-spreads', 'juice-sat-cord-ms'] 0.166
# ['jams-spreads', 'margarine'] 0.179
# ['jams-spreads', 'milk-cream'] 0.188
# ['jams-spreads', 'party snack foods'] 0.162
# ['jams-spreads', 'sauces-gravy-pkle'] 0.163
# ['jams-spreads', 'tissues-paper prd'] 0.167
# ['jams-spreads', 'vegetables'] 0.192
# ['juice-sat-cord-ms', 'laundry needs'] 0.211
# ['juice-sat-cord-ms', 'margarine'] 0.294
# ['juice-sat-cord-ms', 'milk-cream'] 0.354
# ['juice-sat-cord-ms', 'party snack foods'] 0.32
# ['juice-sat-cord-ms', 'pet foods'] 0.238
# ['juice-sat-cord-ms', 'prepared meals'] 0.177
# ['juice-sat-cord-ms', 'sauces-gravy-pkle'] 0.286
# ['juice-sat-cord-ms', 'soft drinks'] 0.248
# ['juice-sat-cord-ms', 'stationary'] 0.168
# ['juice-sat-cord-ms', 'tissues-paper prd'] 0.293
# ['juice-sat-cord-ms', 'vegetables'] 0.358
# ['juice-sat-cord-ms', 'wrapping'] 0.179
# ['laundry needs', 'margarine'] 0.214
# ['laundry needs', 'milk-cream'] 0.229
# ['laundry needs', 'party snack foods'] 0.2
# ['laundry needs', 'pet foods'] 0.172
# ['laundry needs', 'sauces-gravy-pkle'] 0.201
# ['laundry needs', 'soft drinks'] 0.156
# ['laundry needs', 'tissues-paper prd'] 0.222
# ['laundry needs', 'vegetables'] 0.231
# ['margarine', 'milk-cream'] 0.335
# ['margarine', 'party snack foods'] 0.267
# ['margarine', 'pet foods'] 0.232
# ['margarine', 'prepared meals'] 0.164
# ['margarine', 'sauces-gravy-pkle'] 0.273
# ['margarine', 'soft drinks'] 0.216
# ['margarine', 'stationary'] 0.162
# ['margarine', 'tissues-paper prd'] 0.292
# ['margarine', 'vegetables'] 0.343
# ['margarine', 'wrapping'] 0.179
# ['milk-cream', 'party snack foods'] 0.333
# ['milk-cream', 'pet foods'] 0.278
# ['milk-cream', 'prepared meals'] 0.181
# ['milk-cream', 'sauces-gravy-pkle'] 0.321
# ['milk-cream', 'small goods'] 0.167
# ['milk-cream', 'soft drinks'] 0.275
# ['milk-cream', 'stationary'] 0.214
# ['milk-cream', 'tissues-paper prd'] 0.327
# ['milk-cream', 'vegetables'] 0.438
# ['milk-cream', 'wrapping'] 0.196
# ['party snack foods', 'pet foods'] 0.234
# ['party snack foods', 'prepared meals'] 0.177
# ['party snack foods', 'sauces-gravy-pkle'] 0.284
# ['party snack foods', 'soft drinks'] 0.251
# ['party snack foods', 'stationary'] 0.173
# ['party snack foods', 'tissues-paper prd'] 0.281
# ['party snack foods', 'vegetables'] 0.337
# ['party snack foods', 'wrapping'] 0.18
# ['pet foods', 'sauces-gravy-pkle'] 0.222
# ['pet foods', 'soft drinks'] 0.181
# ['pet foods', 'tissues-paper prd'] 0.242
# ['pet foods', 'vegetables'] 0.287
# ['prepared meals', 'sauces-gravy-pkle'] 0.175
# ['prepared meals', 'tissues-paper prd'] 0.168
# ['prepared meals', 'vegetables'] 0.188
# ['sauces-gravy-pkle', 'soft drinks'] 0.214
# ['sauces-gravy-pkle', 'stationary'] 0.161
# ['sauces-gravy-pkle', 'tissues-paper prd'] 0.279
# ['sauces-gravy-pkle', 'vegetables'] 0.337
# ['sauces-gravy-pkle', 'wrapping'] 0.175
# ['small goods', 'vegetables'] 0.178
# ['soft drinks', 'tissues-paper prd'] 0.219
# ['soft drinks', 'vegetables'] 0.264
# ['stationary', 'tissues-paper prd'] 0.173
# ['stationary', 'vegetables'] 0.209
# ['tissues-paper prd', 'vegetables'] 0.337
# ['tissues-paper prd', 'wrapping'] 0.188
# ['vegetables', 'wrapping'] 0.204
# ['baking needs', 'beef', 'biscuits'] 0.167
# ['baking needs', 'beef', 'bread and cake'] 0.208
# ['baking needs', 'beef', 'frozen foods'] 0.184
# ['baking needs', 'beef', 'fruit'] 0.179
# ['baking needs', 'beef', 'margarine'] 0.16
# ['baking needs', 'beef', 'milk-cream'] 0.177
# ['baking needs', 'beef', 'tissues-paper prd'] 0.158
# ['baking needs', 'beef', 'vegetables'] 0.197
# ['baking needs', 'biscuits', 'bread and cake'] 0.315
# ['baking needs', 'biscuits', 'breakfast food'] 0.202
# ['baking needs', 'biscuits', 'canned vegetables'] 0.177
# ['baking needs', 'biscuits', 'cheese'] 0.195
# ['baking needs', 'biscuits', 'confectionary'] 0.172
# ['baking needs', 'biscuits', 'dairy foods'] 0.172
# ['baking needs', 'biscuits', 'department137'] 0.177
# ['baking needs', 'biscuits', 'frozen foods'] 0.284
# ['baking needs', 'biscuits', 'fruit'] 0.276
# ['baking needs', 'biscuits', 'juice-sat-cord-ms'] 0.237
# ['baking needs', 'biscuits', 'laundry needs'] 0.164
# ['baking needs', 'biscuits', 'margarine'] 0.244
# ['baking needs', 'biscuits', 'milk-cream'] 0.266
# ['baking needs', 'biscuits', 'party snack foods'] 0.241
# ['baking needs', 'biscuits', 'pet foods'] 0.186
# ['baking needs', 'biscuits', 'sauces-gravy-pkle'] 0.224
# ['baking needs', 'biscuits', 'soft drinks'] 0.179
# ['baking needs', 'biscuits', 'tissues-paper prd'] 0.233
# ['baking needs', 'biscuits', 'vegetables'] 0.273
# ['baking needs', 'biscuits', 'wrapping'] 0.151
# ['baking needs', 'bread and cake', 'breakfast food'] 0.232
# ['baking needs', 'bread and cake', 'canned fruit'] 0.165
# ['baking needs', 'bread and cake', 'canned vegetables'] 0.203
# ['baking needs', 'bread and cake', 'cheese'] 0.232
# ['baking needs', 'bread and cake', 'cleaners-polishers'] 0.157
# ['baking needs', 'bread and cake', 'confectionary'] 0.19
# ['baking needs', 'bread and cake', 'dairy foods'] 0.201
# ['baking needs', 'bread and cake', 'department137'] 0.215
# ['baking needs', 'bread and cake', 'frozen foods'] 0.321
# ['baking needs', 'bread and cake', 'fruit'] 0.338
# ['baking needs', 'bread and cake', 'jams-spreads'] 0.165
# ['baking needs', 'bread and cake', 'juice-sat-cord-ms'] 0.279
# ['baking needs', 'bread and cake', 'laundry needs'] 0.195
# ['baking needs', 'bread and cake', 'margarine'] 0.293
# ['baking needs', 'bread and cake', 'milk-cream'] 0.341
# ['baking needs', 'bread and cake', 'party snack foods'] 0.271
# ['baking needs', 'bread and cake', 'pet foods'] 0.226
# ['baking needs', 'bread and cake', 'prepared meals'] 0.161
# ['baking needs', 'bread and cake', 'sauces-gravy-pkle'] 0.264
# ['baking needs', 'bread and cake', 'soft drinks'] 0.206
# ['baking needs', 'bread and cake', 'stationary'] 0.163
# ['baking needs', 'bread and cake', 'tissues-paper prd'] 0.28
# ['baking needs', 'bread and cake', 'vegetables'] 0.343
# ['baking needs', 'bread and cake', 'wrapping'] 0.171
# ['baking needs', 'breakfast food', 'cheese'] 0.153
# ['baking needs', 'breakfast food', 'frozen foods'] 0.208
# ['baking needs', 'breakfast food', 'fruit'] 0.206
# ['baking needs', 'breakfast food', 'juice-sat-cord-ms'] 0.187
# ['baking needs', 'breakfast food', 'margarine'] 0.188
# ['baking needs', 'breakfast food', 'milk-cream'] 0.198
# ['baking needs', 'breakfast food', 'party snack foods'] 0.175
# ['baking needs', 'breakfast food', 'sauces-gravy-pkle'] 0.169
# ['baking needs', 'breakfast food', 'tissues-paper prd'] 0.182
# ['baking needs', 'breakfast food', 'vegetables'] 0.205
# ['baking needs', 'canned vegetables', 'frozen foods'] 0.182
# ['baking needs', 'canned vegetables', 'fruit'] 0.177
# ['baking needs', 'canned vegetables', 'juice-sat-cord-ms'] 0.157
# ['baking needs', 'canned vegetables', 'margarine'] 0.166
# ['baking needs', 'canned vegetables', 'milk-cream'] 0.171
# ['baking needs', 'canned vegetables', 'party snack foods'] 0.15
# ['baking needs', 'canned vegetables', 'sauces-gravy-pkle'] 0.156
# ['baking needs', 'canned vegetables', 'tissues-paper prd'] 0.162
# ['baking needs', 'canned vegetables', 'vegetables'] 0.184
# ['baking needs', 'cheese', 'frozen foods'] 0.199
# ['baking needs', 'cheese', 'fruit'] 0.202
# ['baking needs', 'cheese', 'juice-sat-cord-ms'] 0.18
# ['baking needs', 'cheese', 'margarine'] 0.19
# ['baking needs', 'cheese', 'milk-cream'] 0.201
# ['baking needs', 'cheese', 'party snack foods'] 0.175
# ['baking needs', 'cheese', 'sauces-gravy-pkle'] 0.174
# ['baking needs', 'cheese', 'tissues-paper prd'] 0.179
# ['baking needs', 'cheese', 'vegetables'] 0.212
# ['baking needs', 'confectionary', 'frozen foods'] 0.165
# ['baking needs', 'confectionary', 'fruit'] 0.165
# ['baking needs', 'confectionary', 'juice-sat-cord-ms'] 0.15
# ['baking needs', 'confectionary', 'milk-cream'] 0.172
# ['baking needs', 'confectionary', 'party snack foods'] 0.152
# ['baking needs', 'confectionary', 'vegetables'] 0.169
# ['baking needs', 'dairy foods', 'frozen foods'] 0.173
# ['baking needs', 'dairy foods', 'fruit'] 0.18
# ['baking needs', 'dairy foods', 'juice-sat-cord-ms'] 0.153
# ['baking needs', 'dairy foods', 'margarine'] 0.152
# ['baking needs', 'dairy foods', 'milk-cream'] 0.174
# ['baking needs', 'dairy foods', 'party snack foods'] 0.158
# ['baking needs', 'dairy foods', 'vegetables'] 0.179
# ['baking needs', 'department137', 'frozen foods'] 0.181
# ['baking needs', 'department137', 'fruit'] 0.185
# ['baking needs', 'department137', 'juice-sat-cord-ms'] 0.154
# ['baking needs', 'department137', 'margarine'] 0.165
# ['baking needs', 'department137', 'milk-cream'] 0.188
# ['baking needs', 'department137', 'party snack foods'] 0.155
# ['baking needs', 'department137', 'sauces-gravy-pkle'] 0.15
# ['baking needs', 'department137', 'tissues-paper prd'] 0.153
# ['baking needs', 'department137', 'vegetables'] 0.191
# ['baking needs', 'frozen foods', 'fruit'] 0.277
# ['baking needs', 'frozen foods', 'juice-sat-cord-ms'] 0.249
# ['baking needs', 'frozen foods', 'laundry needs'] 0.169
# ['baking needs', 'frozen foods', 'margarine'] 0.252
# ['baking needs', 'frozen foods', 'milk-cream'] 0.276
# ['baking needs', 'frozen foods', 'party snack foods'] 0.24
# ['baking needs', 'frozen foods', 'pet foods'] 0.192
# ['baking needs', 'frozen foods', 'prepared meals'] 0.151
# ['baking needs', 'frozen foods', 'sauces-gravy-pkle'] 0.235
# ['baking needs', 'frozen foods', 'soft drinks'] 0.187
# ['baking needs', 'frozen foods', 'tissues-paper prd'] 0.242
# ['baking needs', 'frozen foods', 'vegetables'] 0.287
# ['baking needs', 'frozen foods', 'wrapping'] 0.154
# ['baking needs', 'fruit', 'juice-sat-cord-ms'] 0.241
# ['baking needs', 'fruit', 'laundry needs'] 0.165
# ['baking needs', 'fruit', 'margarine'] 0.244
# ['baking needs', 'fruit', 'milk-cream'] 0.295
# ['baking needs', 'fruit', 'party snack foods'] 0.231
# ['baking needs', 'fruit', 'pet foods'] 0.194
# ['baking needs', 'fruit', 'sauces-gravy-pkle'] 0.226
# ['baking needs', 'fruit', 'soft drinks'] 0.181
# ['baking needs', 'fruit', 'tissues-paper prd'] 0.241
# ['baking needs', 'fruit', 'vegetables'] 0.322
# ['baking needs', 'juice-sat-cord-ms', 'laundry needs'] 0.155
# ['baking needs', 'juice-sat-cord-ms', 'margarine'] 0.22
# ['baking needs', 'juice-sat-cord-ms', 'milk-cream'] 0.24
# ['baking needs', 'juice-sat-cord-ms', 'party snack foods'] 0.223
# ['baking needs', 'juice-sat-cord-ms', 'pet foods'] 0.167
# ['baking needs', 'juice-sat-cord-ms', 'sauces-gravy-pkle'] 0.205
# ['baking needs', 'juice-sat-cord-ms', 'soft drinks'] 0.164
# ['baking needs', 'juice-sat-cord-ms', 'tissues-paper prd'] 0.213
# ['baking needs', 'juice-sat-cord-ms', 'vegetables'] 0.248
# ['baking needs', 'laundry needs', 'margarine'] 0.163
# ['baking needs', 'laundry needs', 'milk-cream'] 0.165
# ['baking needs', 'laundry needs', 'sauces-gravy-pkle'] 0.151
# ['baking needs', 'laundry needs', 'tissues-paper prd'] 0.167
# ['baking needs', 'laundry needs', 'vegetables'] 0.168
# ['baking needs', 'margarine', 'milk-cream'] 0.247
# ['baking needs', 'margarine', 'party snack foods'] 0.2
# ['baking needs', 'margarine', 'pet foods'] 0.176
# ['baking needs', 'margarine', 'sauces-gravy-pkle'] 0.207
# ['baking needs', 'margarine', 'soft drinks'] 0.156
# ['baking needs', 'margarine', 'tissues-paper prd'] 0.225
# ['baking needs', 'margarine', 'vegetables'] 0.255
# ['baking needs', 'milk-cream', 'party snack foods'] 0.227
# ['baking needs', 'milk-cream', 'pet foods'] 0.196
# ['baking needs', 'milk-cream', 'sauces-gravy-pkle'] 0.228
# ['baking needs', 'milk-cream', 'soft drinks'] 0.183
# ['baking needs', 'milk-cream', 'tissues-paper prd'] 0.239
# ['baking needs', 'milk-cream', 'vegetables'] 0.301
# ['baking needs', 'party snack foods', 'pet foods'] 0.166
# ['baking needs', 'party snack foods', 'sauces-gravy-pkle'] 0.206
# ['baking needs', 'party snack foods', 'soft drinks'] 0.164
# ['baking needs', 'party snack foods', 'tissues-paper prd'] 0.203
# ['baking needs', 'party snack foods', 'vegetables'] 0.235
# ['baking needs', 'pet foods', 'sauces-gravy-pkle'] 0.163
# ['baking needs', 'pet foods', 'tissues-paper prd'] 0.179
# ['baking needs', 'pet foods', 'vegetables'] 0.204
# ['baking needs', 'sauces-gravy-pkle', 'soft drinks'] 0.151
# ['baking needs', 'sauces-gravy-pkle', 'tissues-paper prd'] 0.209
# ['baking needs', 'sauces-gravy-pkle', 'vegetables'] 0.241
# ['baking needs', 'soft drinks', 'tissues-paper prd'] 0.159
# ['baking needs', 'soft drinks', 'vegetables'] 0.18
# ['baking needs', 'tissues-paper prd', 'vegetables'] 0.246
# ['baking needs', 'vegetables', 'wrapping'] 0.156
# ['beef', 'biscuits', 'bread and cake'] 0.195
# ['beef', 'biscuits', 'frozen foods'] 0.178
# ['beef', 'biscuits', 'fruit'] 0.169
# ['beef', 'biscuits', 'milk-cream'] 0.159
# ['beef', 'biscuits', 'vegetables'] 0.176
# ['beef', 'bread and cake', 'frozen foods'] 0.212
# ['beef', 'bread and cake', 'fruit'] 0.215
# ['beef', 'bread and cake', 'juice-sat-cord-ms'] 0.172
# ['beef', 'bread and cake', 'margarine'] 0.175
# ['beef', 'bread and cake', 'milk-cream'] 0.212
# ['beef', 'bread and cake', 'party snack foods'] 0.164
# ['beef', 'bread and cake', 'pet foods'] 0.157
# ['beef', 'bread and cake', 'sauces-gravy-pkle'] 0.17
# ['beef', 'bread and cake', 'tissues-paper prd'] 0.178
# ['beef', 'bread and cake', 'vegetables'] 0.23
# ['beef', 'frozen foods', 'fruit'] 0.182
# ['beef', 'frozen foods', 'juice-sat-cord-ms'] 0.156
# ['beef', 'frozen foods', 'margarine'] 0.16
# ['beef', 'frozen foods', 'milk-cream'] 0.182
# ['beef', 'frozen foods', 'party snack foods'] 0.155
# ['beef', 'frozen foods', 'sauces-gravy-pkle'] 0.155
# ['beef', 'frozen foods', 'tissues-paper prd'] 0.157
# ['beef', 'frozen foods', 'vegetables'] 0.199
# ['beef', 'fruit', 'juice-sat-cord-ms'] 0.155
# ['beef', 'fruit', 'milk-cream'] 0.181
# ['beef', 'fruit', 'tissues-paper prd'] 0.155
# ['beef', 'fruit', 'vegetables'] 0.213
# ['beef', 'juice-sat-cord-ms', 'vegetables'] 0.164
# ['beef', 'margarine', 'vegetables'] 0.163
# ['beef', 'milk-cream', 'vegetables'] 0.198
# ['beef', 'sauces-gravy-pkle', 'vegetables'] 0.157
# ['beef', 'tissues-paper prd', 'vegetables'] 0.165
# ['biscuits', 'bread and cake', 'breakfast food'] 0.22
# ['biscuits', 'bread and cake', 'canned fruit'] 0.163
# ['biscuits', 'bread and cake', 'canned vegetables'] 0.198
# ['biscuits', 'bread and cake', 'cheese'] 0.222
# ['biscuits', 'bread and cake', 'confectionary'] 0.199
# ['biscuits', 'bread and cake', 'dairy foods'] 0.198
# ['biscuits', 'bread and cake', 'department137'] 0.209
# ['biscuits', 'bread and cake', 'frozen foods'] 0.326
# ['biscuits', 'bread and cake', 'fruit'] 0.333
# ['biscuits', 'bread and cake', 'jams-spreads'] 0.161
# ['biscuits', 'bread and cake', 'juice-sat-cord-ms'] 0.272
# ['biscuits', 'bread and cake', 'laundry needs'] 0.183
# ['biscuits', 'bread and cake', 'margarine'] 0.27
# ['biscuits', 'bread and cake', 'milk-cream'] 0.321
# ['biscuits', 'bread and cake', 'party snack foods'] 0.282
# ['biscuits', 'bread and cake', 'pet foods'] 0.216
# ['biscuits', 'bread and cake', 'prepared meals'] 0.15
# ['biscuits', 'bread and cake', 'sauces-gravy-pkle'] 0.248
# ['biscuits', 'bread and cake', 'soft drinks'] 0.209
# ['biscuits', 'bread and cake', 'stationary'] 0.159
# ['biscuits', 'bread and cake', 'tissues-paper prd'] 0.261
# ['biscuits', 'bread and cake', 'vegetables'] 0.321
# ['biscuits', 'bread and cake', 'wrapping'] 0.163
# ['biscuits', 'breakfast food', 'frozen foods'] 0.203
# ['biscuits', 'breakfast food', 'fruit'] 0.195
# ['biscuits', 'breakfast food', 'juice-sat-cord-ms'] 0.178
# ['biscuits', 'breakfast food', 'margarine'] 0.172
# ['biscuits', 'breakfast food', 'milk-cream'] 0.184
# ['biscuits', 'breakfast food', 'party snack foods'] 0.178
# ['biscuits', 'breakfast food', 'sauces-gravy-pkle'] 0.16
# ['biscuits', 'breakfast food', 'tissues-paper prd'] 0.17
# ['biscuits', 'breakfast food', 'vegetables'] 0.189
# ['biscuits', 'canned vegetables', 'frozen foods'] 0.185
# ['biscuits', 'canned vegetables', 'fruit'] 0.177
# ['biscuits', 'canned vegetables', 'juice-sat-cord-ms'] 0.156
# ['biscuits', 'canned vegetables', 'margarine'] 0.16
# ['biscuits', 'canned vegetables', 'milk-cream'] 0.162
# ['biscuits', 'canned vegetables', 'party snack foods'] 0.152
# ['biscuits', 'canned vegetables', 'sauces-gravy-pkle'] 0.157
# ['biscuits', 'canned vegetables', 'tissues-paper prd'] 0.155
# ['biscuits', 'canned vegetables', 'vegetables'] 0.176
# ['biscuits', 'cheese', 'frozen foods'] 0.198
# ['biscuits', 'cheese', 'fruit'] 0.196
# ['biscuits', 'cheese', 'juice-sat-cord-ms'] 0.175
# ['biscuits', 'cheese', 'margarine'] 0.18
# ['biscuits', 'cheese', 'milk-cream'] 0.186
# ['biscuits', 'cheese', 'party snack foods'] 0.178
# ['biscuits', 'cheese', 'sauces-gravy-pkle'] 0.166
# ['biscuits', 'cheese', 'tissues-paper prd'] 0.171
# ['biscuits', 'cheese', 'vegetables'] 0.196
# ['biscuits', 'confectionary', 'frozen foods'] 0.171
# ['biscuits', 'confectionary', 'fruit'] 0.176
# ['biscuits', 'confectionary', 'juice-sat-cord-ms'] 0.156
# ['biscuits', 'confectionary', 'margarine'] 0.15
# ['biscuits', 'confectionary', 'milk-cream'] 0.175
# ['biscuits', 'confectionary', 'party snack foods'] 0.164
# ['biscuits', 'confectionary', 'vegetables'] 0.166
# ['biscuits', 'dairy foods', 'frozen foods'] 0.174
# ['biscuits', 'dairy foods', 'fruit'] 0.182
# ['biscuits', 'dairy foods', 'juice-sat-cord-ms'] 0.155
# ['biscuits', 'dairy foods', 'milk-cream'] 0.168
# ['biscuits', 'dairy foods', 'party snack foods'] 0.165
# ['biscuits', 'dairy foods', 'vegetables'] 0.172
# ['biscuits', 'department137', 'frozen foods'] 0.183
# ['biscuits', 'department137', 'fruit'] 0.182
# ['biscuits', 'department137', 'margarine'] 0.152
# ['biscuits', 'department137', 'milk-cream'] 0.175
# ['biscuits', 'department137', 'party snack foods'] 0.163
# ['biscuits', 'department137', 'vegetables'] 0.179
# ['biscuits', 'frozen foods', 'fruit'] 0.283
# ['biscuits', 'frozen foods', 'juice-sat-cord-ms'] 0.247
# ['biscuits', 'frozen foods', 'laundry needs'] 0.167
# ['biscuits', 'frozen foods', 'margarine'] 0.241
# ['biscuits', 'frozen foods', 'milk-cream'] 0.271
# ['biscuits', 'frozen foods', 'party snack foods'] 0.255
# ['biscuits', 'frozen foods', 'pet foods'] 0.193
# ['biscuits', 'frozen foods', 'sauces-gravy-pkle'] 0.233
# ['biscuits', 'frozen foods', 'soft drinks'] 0.19
# ['biscuits', 'frozen foods', 'tissues-paper prd'] 0.232
# ['biscuits', 'frozen foods', 'vegetables'] 0.279
# ['biscuits', 'fruit', 'juice-sat-cord-ms'] 0.242
# ['biscuits', 'fruit', 'laundry needs'] 0.156
# ['biscuits', 'fruit', 'margarine'] 0.232
# ['biscuits', 'fruit', 'milk-cream'] 0.281
# ['biscuits', 'fruit', 'party snack foods'] 0.249
# ['biscuits', 'fruit', 'pet foods'] 0.189
# ['biscuits', 'fruit', 'sauces-gravy-pkle'] 0.219
# ['biscuits', 'fruit', 'soft drinks'] 0.185
# ['biscuits', 'fruit', 'tissues-paper prd'] 0.231
# ['biscuits', 'fruit', 'vegetables'] 0.303
# ['biscuits', 'juice-sat-cord-ms', 'margarine'] 0.207
# ['biscuits', 'juice-sat-cord-ms', 'milk-cream'] 0.229
# ['biscuits', 'juice-sat-cord-ms', 'party snack foods'] 0.231
# ['biscuits', 'juice-sat-cord-ms', 'pet foods'] 0.165
# ['biscuits', 'juice-sat-cord-ms', 'sauces-gravy-pkle'] 0.196
# ['biscuits', 'juice-sat-cord-ms', 'soft drinks'] 0.164
# ['biscuits', 'juice-sat-cord-ms', 'tissues-paper prd'] 0.203
# ['biscuits', 'juice-sat-cord-ms', 'vegetables'] 0.232
# ['biscuits', 'laundry needs', 'margarine'] 0.15
# ['biscuits', 'laundry needs', 'milk-cream'] 0.153
# ['biscuits', 'laundry needs', 'party snack foods'] 0.152
# ['biscuits', 'laundry needs', 'tissues-paper prd'] 0.153
# ['biscuits', 'laundry needs', 'vegetables'] 0.155
# ['biscuits', 'margarine', 'milk-cream'] 0.224
# ['biscuits', 'margarine', 'party snack foods'] 0.2
# ['biscuits', 'margarine', 'pet foods'] 0.161
# ['biscuits', 'margarine', 'sauces-gravy-pkle'] 0.19
# ['biscuits', 'margarine', 'soft drinks'] 0.155
# ['biscuits', 'margarine', 'tissues-paper prd'] 0.204
# ['biscuits', 'margarine', 'vegetables'] 0.228
# ['biscuits', 'milk-cream', 'party snack foods'] 0.235
# ['biscuits', 'milk-cream', 'pet foods'] 0.182
# ['biscuits', 'milk-cream', 'sauces-gravy-pkle'] 0.209
# ['biscuits', 'milk-cream', 'soft drinks'] 0.182
# ['biscuits', 'milk-cream', 'tissues-paper prd'] 0.215
# ['biscuits', 'milk-cream', 'vegetables'] 0.267
# ['biscuits', 'party snack foods', 'pet foods'] 0.172
# ['biscuits', 'party snack foods', 'sauces-gravy-pkle'] 0.208
# ['biscuits', 'party snack foods', 'soft drinks'] 0.177
# ['biscuits', 'party snack foods', 'tissues-paper prd'] 0.208
# ['biscuits', 'party snack foods', 'vegetables'] 0.24
# ['biscuits', 'pet foods', 'sauces-gravy-pkle'] 0.158
# ['biscuits', 'pet foods', 'tissues-paper prd'] 0.167
# ['biscuits', 'pet foods', 'vegetables'] 0.189
# ['biscuits', 'sauces-gravy-pkle', 'soft drinks'] 0.15
# ['biscuits', 'sauces-gravy-pkle', 'tissues-paper prd'] 0.193
# ['biscuits', 'sauces-gravy-pkle', 'vegetables'] 0.221
# ['biscuits', 'soft drinks', 'tissues-paper prd'] 0.154
# ['biscuits', 'soft drinks', 'vegetables'] 0.174
# ['biscuits', 'tissues-paper prd', 'vegetables'] 0.225
# ['bread and cake', 'breakfast food', 'cheese'] 0.16
# ['bread and cake', 'breakfast food', 'frozen foods'] 0.219
# ['bread and cake', 'breakfast food', 'fruit'] 0.231
# ['bread and cake', 'breakfast food', 'juice-sat-cord-ms'] 0.2
# ['bread and cake', 'breakfast food', 'margarine'] 0.195
# ['bread and cake', 'breakfast food', 'milk-cream'] 0.225
# ['bread and cake', 'breakfast food', 'party snack foods'] 0.192
# ['bread and cake', 'breakfast food', 'pet foods'] 0.154
# ['bread and cake', 'breakfast food', 'sauces-gravy-pkle'] 0.178
# ['bread and cake', 'breakfast food', 'tissues-paper prd'] 0.191
# ['bread and cake', 'breakfast food', 'vegetables'] 0.227
# ['bread and cake', 'canned fruit', 'frozen foods'] 0.165
# ['bread and cake', 'canned fruit', 'fruit'] 0.173
# ['bread and cake', 'canned fruit', 'milk-cream'] 0.166
# ['bread and cake', 'canned fruit', 'vegetables'] 0.166
# ['bread and cake', 'canned vegetables', 'frozen foods'] 0.199
# ['bread and cake', 'canned vegetables', 'fruit'] 0.205
# ['bread and cake', 'canned vegetables', 'juice-sat-cord-ms'] 0.169
# ['bread and cake', 'canned vegetables', 'margarine'] 0.174
# ['bread and cake', 'canned vegetables', 'milk-cream'] 0.194
# ['bread and cake', 'canned vegetables', 'party snack foods'] 0.164
# ['bread and cake', 'canned vegetables', 'sauces-gravy-pkle'] 0.173
# ['bread and cake', 'canned vegetables', 'tissues-paper prd'] 0.175
# ['bread and cake', 'canned vegetables', 'vegetables'] 0.209
# ['bread and cake', 'cheese', 'department137'] 0.155
# ['bread and cake', 'cheese', 'frozen foods'] 0.221
# ['bread and cake', 'cheese', 'fruit'] 0.24
# ['bread and cake', 'cheese', 'juice-sat-cord-ms'] 0.2
# ['bread and cake', 'cheese', 'margarine'] 0.209
# ['bread and cake', 'cheese', 'milk-cream'] 0.232
# ['bread and cake', 'cheese', 'party snack foods'] 0.198
# ['bread and cake', 'cheese', 'pet foods'] 0.159
# ['bread and cake', 'cheese', 'sauces-gravy-pkle'] 0.19
# ['bread and cake', 'cheese', 'tissues-paper prd'] 0.199
# ['bread and cake', 'cheese', 'vegetables'] 0.24
# ['bread and cake', 'cleaners-polishers', 'frozen foods'] 0.15
# ['bread and cake', 'cleaners-polishers', 'fruit'] 0.153
# ['bread and cake', 'cleaners-polishers', 'milk-cream'] 0.153
# ['bread and cake', 'cleaners-polishers', 'vegetables'] 0.156
# ['bread and cake', 'confectionary', 'frozen foods'] 0.188
# ['bread and cake', 'confectionary', 'fruit'] 0.202
# ['bread and cake', 'confectionary', 'juice-sat-cord-ms'] 0.17
# ['bread and cake', 'confectionary', 'margarine'] 0.163
# ['bread and cake', 'confectionary', 'milk-cream'] 0.204
# ['bread and cake', 'confectionary', 'party snack foods'] 0.177
# ['bread and cake', 'confectionary', 'tissues-paper prd'] 0.158
# ['bread and cake', 'confectionary', 'vegetables'] 0.193
# ['bread and cake', 'dairy foods', 'frozen foods'] 0.197
# ['bread and cake', 'dairy foods', 'fruit'] 0.214
# ['bread and cake', 'dairy foods', 'juice-sat-cord-ms'] 0.177
# ['bread and cake', 'dairy foods', 'margarine'] 0.17
# ['bread and cake', 'dairy foods', 'milk-cream'] 0.204
# ['bread and cake', 'dairy foods', 'party snack foods'] 0.182
# ['bread and cake', 'dairy foods', 'sauces-gravy-pkle'] 0.163
# ['bread and cake', 'dairy foods', 'tissues-paper prd'] 0.164
# ['bread and cake', 'dairy foods', 'vegetables'] 0.209
# ['bread and cake', 'department137', 'frozen foods'] 0.211
# ['bread and cake', 'department137', 'fruit'] 0.23
# ['bread and cake', 'department137', 'juice-sat-cord-ms'] 0.182
# ['bread and cake', 'department137', 'margarine'] 0.183
# ['bread and cake', 'department137', 'milk-cream'] 0.232
# ['bread and cake', 'department137', 'party snack foods'] 0.184
# ['bread and cake', 'department137', 'pet foods'] 0.153
# ['bread and cake', 'department137', 'sauces-gravy-pkle'] 0.172
# ['bread and cake', 'department137', 'tissues-paper prd'] 0.175
# ['bread and cake', 'department137', 'vegetables'] 0.23
# ['bread and cake', 'frozen foods', 'fruit'] 0.335
# ['bread and cake', 'frozen foods', 'jams-spreads'] 0.156
# ['bread and cake', 'frozen foods', 'juice-sat-cord-ms'] 0.277
# ['bread and cake', 'frozen foods', 'laundry needs'] 0.187
# ['bread and cake', 'frozen foods', 'margarine'] 0.27
# ['bread and cake', 'frozen foods', 'milk-cream'] 0.328
# ['bread and cake', 'frozen foods', 'party snack foods'] 0.277
# ['bread and cake', 'frozen foods', 'pet foods'] 0.223
# ['bread and cake', 'frozen foods', 'prepared meals'] 0.165
# ['bread and cake', 'frozen foods', 'sauces-gravy-pkle'] 0.262
# ['bread and cake', 'frozen foods', 'soft drinks'] 0.219
# ['bread and cake', 'frozen foods', 'stationary'] 0.158
# ['bread and cake', 'frozen foods', 'tissues-paper prd'] 0.268
# ['bread and cake', 'frozen foods', 'vegetables'] 0.335
# ['bread and cake', 'frozen foods', 'wrapping'] 0.164
# ['bread and cake', 'fruit', 'jams-spreads'] 0.164
# ['bread and cake', 'fruit', 'juice-sat-cord-ms'] 0.293
# ['bread and cake', 'fruit', 'laundry needs'] 0.194
# ['bread and cake', 'fruit', 'margarine'] 0.281
# ['bread and cake', 'fruit', 'milk-cream'] 0.364
# ['bread and cake', 'fruit', 'party snack foods'] 0.285
# ['bread and cake', 'fruit', 'pet foods'] 0.236
# ['bread and cake', 'fruit', 'prepared meals'] 0.156
# ['bread and cake', 'fruit', 'sauces-gravy-pkle'] 0.265
# ['bread and cake', 'fruit', 'soft drinks'] 0.222
# ['bread and cake', 'fruit', 'stationary'] 0.174
# ['bread and cake', 'fruit', 'tissues-paper prd'] 0.28
# ['bread and cake', 'fruit', 'vegetables'] 0.387
# ['bread and cake', 'fruit', 'wrapping'] 0.166
# ['bread and cake', 'jams-spreads', 'milk-cream'] 0.162
# ['bread and cake', 'jams-spreads', 'vegetables'] 0.161
# ['bread and cake', 'juice-sat-cord-ms', 'laundry needs'] 0.167
# ['bread and cake', 'juice-sat-cord-ms', 'margarine'] 0.238
# ['bread and cake', 'juice-sat-cord-ms', 'milk-cream'] 0.288
# ['bread and cake', 'juice-sat-cord-ms', 'party snack foods'] 0.255
# ['bread and cake', 'juice-sat-cord-ms', 'pet foods'] 0.194
# ['bread and cake', 'juice-sat-cord-ms', 'sauces-gravy-pkle'] 0.225
# ['bread and cake', 'juice-sat-cord-ms', 'soft drinks'] 0.192
# ['bread and cake', 'juice-sat-cord-ms', 'tissues-paper prd'] 0.237
# ['bread and cake', 'juice-sat-cord-ms', 'vegetables'] 0.286
# ['bread and cake', 'laundry needs', 'margarine'] 0.172
# ['bread and cake', 'laundry needs', 'milk-cream'] 0.193
# ['bread and cake', 'laundry needs', 'party snack foods'] 0.165
# ['bread and cake', 'laundry needs', 'sauces-gravy-pkle'] 0.165
# ['bread and cake', 'laundry needs', 'tissues-paper prd'] 0.182
# ['bread and cake', 'laundry needs', 'vegetables'] 0.192
# ['bread and cake', 'margarine', 'milk-cream'] 0.281
# ['bread and cake', 'margarine', 'party snack foods'] 0.221
# ['bread and cake', 'margarine', 'pet foods'] 0.196
# ['bread and cake', 'margarine', 'sauces-gravy-pkle'] 0.223
# ['bread and cake', 'margarine', 'soft drinks'] 0.174
# ['bread and cake', 'margarine', 'tissues-paper prd'] 0.241
# ['bread and cake', 'margarine', 'vegetables'] 0.286
# ['bread and cake', 'milk-cream', 'party snack foods'] 0.276
# ['bread and cake', 'milk-cream', 'pet foods'] 0.234
# ['bread and cake', 'milk-cream', 'prepared meals'] 0.152
# ['bread and cake', 'milk-cream', 'sauces-gravy-pkle'] 0.263
# ['bread and cake', 'milk-cream', 'soft drinks'] 0.224
# ['bread and cake', 'milk-cream', 'stationary'] 0.174
# ['bread and cake', 'milk-cream', 'tissues-paper prd'] 0.276
# ['bread and cake', 'milk-cream', 'vegetables'] 0.358
# ['bread and cake', 'milk-cream', 'wrapping'] 0.163
# ['bread and cake', 'party snack foods', 'pet foods'] 0.194
# ['bread and cake', 'party snack foods', 'sauces-gravy-pkle'] 0.23
# ['bread and cake', 'party snack foods', 'soft drinks'] 0.196
# ['bread and cake', 'party snack foods', 'tissues-paper prd'] 0.231
# ['bread and cake', 'party snack foods', 'vegetables'] 0.275
# ['bread and cake', 'pet foods', 'sauces-gravy-pkle'] 0.185
# ['bread and cake', 'pet foods', 'tissues-paper prd'] 0.2
# ['bread and cake', 'pet foods', 'vegetables'] 0.239
# ['bread and cake', 'prepared meals', 'vegetables'] 0.156
# ['bread and cake', 'sauces-gravy-pkle', 'soft drinks'] 0.17
# ['bread and cake', 'sauces-gravy-pkle', 'tissues-paper prd'] 0.226
# ['bread and cake', 'sauces-gravy-pkle', 'vegetables'] 0.274
# ['bread and cake', 'small goods', 'vegetables'] 0.151
# ['bread and cake', 'soft drinks', 'tissues-paper prd'] 0.177
# ['bread and cake', 'soft drinks', 'vegetables'] 0.211
# ['bread and cake', 'stationary', 'vegetables'] 0.17
# ['bread and cake', 'tissues-paper prd', 'vegetables'] 0.279
# ['bread and cake', 'tissues-paper prd', 'wrapping'] 0.154
# ['bread and cake', 'vegetables', 'wrapping'] 0.169
# ['breakfast food', 'frozen foods', 'fruit'] 0.194
# ['breakfast food', 'frozen foods', 'juice-sat-cord-ms'] 0.181
# ['breakfast food', 'frozen foods', 'margarine'] 0.172
# ['breakfast food', 'frozen foods', 'milk-cream'] 0.184
# ['breakfast food', 'frozen foods', 'party snack foods'] 0.175
# ['breakfast food', 'frozen foods', 'sauces-gravy-pkle'] 0.166
# ['breakfast food', 'frozen foods', 'tissues-paper prd'] 0.172
# ['breakfast food', 'frozen foods', 'vegetables'] 0.197
# ['breakfast food', 'fruit', 'juice-sat-cord-ms'] 0.18
# ['breakfast food', 'fruit', 'margarine'] 0.168
# ['breakfast food', 'fruit', 'milk-cream'] 0.203
# ['breakfast food', 'fruit', 'party snack foods'] 0.171
# ['breakfast food', 'fruit', 'sauces-gravy-pkle'] 0.161
# ['breakfast food', 'fruit', 'tissues-paper prd'] 0.172
# ['breakfast food', 'fruit', 'vegetables'] 0.221
# ['breakfast food', 'juice-sat-cord-ms', 'margarine'] 0.157
# ['breakfast food', 'juice-sat-cord-ms', 'milk-cream'] 0.171
# ['breakfast food', 'juice-sat-cord-ms', 'party snack foods'] 0.165
# ['breakfast food', 'juice-sat-cord-ms', 'tissues-paper prd'] 0.157
# ['breakfast food', 'juice-sat-cord-ms', 'vegetables'] 0.176
# ['breakfast food', 'margarine', 'milk-cream'] 0.165
# ['breakfast food', 'margarine', 'tissues-paper prd'] 0.155
# ['breakfast food', 'margarine', 'vegetables'] 0.17
# ['breakfast food', 'milk-cream', 'party snack foods'] 0.162
# ['breakfast food', 'milk-cream', 'sauces-gravy-pkle'] 0.151
# ['breakfast food', 'milk-cream', 'tissues-paper prd'] 0.161
# ['breakfast food', 'milk-cream', 'vegetables'] 0.196
# ['breakfast food', 'party snack foods', 'tissues-paper prd'] 0.152
# ['breakfast food', 'party snack foods', 'vegetables'] 0.166
# ['breakfast food', 'sauces-gravy-pkle', 'vegetables'] 0.162
# ['breakfast food', 'tissues-paper prd', 'vegetables'] 0.171
# ['canned fruit', 'fruit', 'vegetables'] 0.161
# ['canned vegetables', 'frozen foods', 'fruit'] 0.175
# ['canned vegetables', 'frozen foods', 'juice-sat-cord-ms'] 0.16
# ['canned vegetables', 'frozen foods', 'margarine'] 0.161
# ['canned vegetables', 'frozen foods', 'milk-cream'] 0.166
# ['canned vegetables', 'frozen foods', 'party snack foods'] 0.154
# ['canned vegetables', 'frozen foods', 'sauces-gravy-pkle'] 0.159
# ['canned vegetables', 'frozen foods', 'tissues-paper prd'] 0.155
# ['canned vegetables', 'frozen foods', 'vegetables'] 0.182
# ['canned vegetables', 'fruit', 'juice-sat-cord-ms'] 0.153
# ['canned vegetables', 'fruit', 'margarine'] 0.155
# ['canned vegetables', 'fruit', 'milk-cream'] 0.174
# ['canned vegetables', 'fruit', 'sauces-gravy-pkle'] 0.155
# ['canned vegetables', 'fruit', 'tissues-paper prd'] 0.154
# ['canned vegetables', 'fruit', 'vegetables'] 0.198
# ['canned vegetables', 'juice-sat-cord-ms', 'vegetables'] 0.155
# ['canned vegetables', 'margarine', 'vegetables'] 0.159
# ['canned vegetables', 'milk-cream', 'vegetables'] 0.175
# ['canned vegetables', 'sauces-gravy-pkle', 'vegetables'] 0.163
# ['canned vegetables', 'tissues-paper prd', 'vegetables'] 0.157
# ['cheese', 'frozen foods', 'fruit'] 0.192
# ['cheese', 'frozen foods', 'juice-sat-cord-ms'] 0.177
# ['cheese', 'frozen foods', 'margarine'] 0.179
# ['cheese', 'frozen foods', 'milk-cream'] 0.187
# ['cheese', 'frozen foods', 'party snack foods'] 0.173
# ['cheese', 'frozen foods', 'sauces-gravy-pkle'] 0.167
# ['cheese', 'frozen foods', 'tissues-paper prd'] 0.172
# ['cheese', 'frozen foods', 'vegetables'] 0.196
# ['cheese', 'fruit', 'juice-sat-cord-ms'] 0.178
# ['cheese', 'fruit', 'margarine'] 0.178
# ['cheese', 'fruit', 'milk-cream'] 0.204
# ['cheese', 'fruit', 'party snack foods'] 0.173
# ['cheese', 'fruit', 'sauces-gravy-pkle'] 0.165
# ['cheese', 'fruit', 'tissues-paper prd'] 0.175
# ['cheese', 'fruit', 'vegetables'] 0.225
# ['cheese', 'juice-sat-cord-ms', 'margarine'] 0.164
# ['cheese', 'juice-sat-cord-ms', 'milk-cream'] 0.17
# ['cheese', 'juice-sat-cord-ms', 'party snack foods'] 0.164
# ['cheese', 'juice-sat-cord-ms', 'sauces-gravy-pkle'] 0.155
# ['cheese', 'juice-sat-cord-ms', 'tissues-paper prd'] 0.159
# ['cheese', 'juice-sat-cord-ms', 'vegetables'] 0.183
# ['cheese', 'margarine', 'milk-cream'] 0.172
# ['cheese', 'margarine', 'party snack foods'] 0.154
# ['cheese', 'margarine', 'sauces-gravy-pkle'] 0.158
# ['cheese', 'margarine', 'tissues-paper prd'] 0.164
# ['cheese', 'margarine', 'vegetables'] 0.184
# ['cheese', 'milk-cream', 'party snack foods'] 0.165
# ['cheese', 'milk-cream', 'sauces-gravy-pkle'] 0.165
# ['cheese', 'milk-cream', 'tissues-paper prd'] 0.166
# ['cheese', 'milk-cream', 'vegetables'] 0.206
# ['cheese', 'party snack foods', 'sauces-gravy-pkle'] 0.155
# ['cheese', 'party snack foods', 'tissues-paper prd'] 0.154
# ['cheese', 'party snack foods', 'vegetables'] 0.173
# ['cheese', 'sauces-gravy-pkle', 'tissues-paper prd'] 0.153
# ['cheese', 'sauces-gravy-pkle', 'vegetables'] 0.174
# ['cheese', 'tissues-paper prd', 'vegetables'] 0.177
# ['confectionary', 'frozen foods', 'fruit'] 0.169
# ['confectionary', 'frozen foods', 'milk-cream'] 0.167
# ['confectionary', 'frozen foods', 'party snack foods'] 0.157
# ...
# {'rule': "['laundry needs', 'party snack foods']-->['bread and cake']", 'length': 3, 'lift': 1.15, 'confidence': 0.828, 'support': 0.165}
# {'rule': "['biscuits', 'wrapping']-->['bread and cake']", 'length': 3, 'lift': 1.15, 'confidence': 0.828, 'support': 0.163}
# {'rule': "['baking needs', 'prepared meals']-->['bread and cake']", 'length': 3, 'lift': 1.15, 'confidence': 0.828, 'support': 0.161}
# {'rule': "['cleaners-polishers', 'frozen foods']-->['bread and cake']", 'length': 3, 'lift': 1.15, 'confidence': 0.828, 'support': 0.15}
# {'rule': "['milk-cream', 'party snack foods']-->['bread and cake']", 'length': 3, 'lift': 1.15, 'confidence': 0.827, 'support': 0.276}
# {'rule': "['canned vegetables', 'frozen foods']-->['bread and cake']", 'length': 3, 'lift': 1.15, 'confidence': 0.827, 'support': 0.199}
# {'rule': "['biscuits', 'laundry needs']-->['bread and cake']", 'length': 3, 'lift': 1.149, 'confidence': 0.827, 'support': 0.183}
# {'rule': "['fruit', 'milk-cream']-->['bread and cake']", 'length': 3, 'lift': 1.148, 'confidence': 0.826, 'support': 0.364}
# {'rule': "['breakfast food', 'milk-cream']-->['bread and cake']", 'length': 3, 'lift': 1.148, 'confidence': 0.826, 'support': 0.225}
# {'rule': "['pet foods', 'tissues-paper prd']-->['bread and cake']", 'length': 3, 'lift': 1.148, 'confidence': 0.826, 'support': 0.2}
# {'rule': "['confectionary', 'margarine']-->['bread and cake']", 'length': 3, 'lift': 1.148, 'confidence': 0.826, 'support': 0.163}
# {'rule': "['biscuits', 'prepared meals']-->['bread and cake']", 'length': 3, 'lift': 1.148, 'confidence': 0.826, 'support': 0.15}
# {'rule': "['baking needs', 'margarine']-->['bread and cake']", 'length': 3, 'lift': 1.147, 'confidence': 0.826, 'support': 0.293}
# {'rule': "['dairy foods', 'milk-cream']-->['bread and cake']", 'length': 3, 'lift': 1.147, 'confidence': 0.826, 'support': 0.204}
# {'rule': "['beef', 'party snack foods']-->['bread and cake']", 'length': 3, 'lift': 1.147, 'confidence': 0.826, 'support': 0.164}
# {'rule': "['baking needs', 'biscuits']-->['bread and cake']", 'length': 3, 'lift': 1.147, 'confidence': 0.825, 'support': 0.315}
# {'rule': "['cheese', 'margarine']-->['bread and cake']", 'length': 3, 'lift': 1.147, 'confidence': 0.825, 'support': 0.209}
# {'rule': "['baking needs', 'canned vegetables']-->['bread and cake']", 'length': 3, 'lift': 1.147, 'confidence': 0.825, 'support': 0.203}
# {'rule': "['cheese', 'party snack foods']-->['bread and cake']", 'length': 3, 'lift': 1.147, 'confidence': 0.825, 'support': 0.198}
# {'rule': "['vegetables', 'wrapping']-->['bread and cake']", 'length': 3, 'lift': 1.147, 'confidence': 0.825, 'support': 0.169}
# {'rule': "['margarine', 'tissues-paper prd']-->['bread and cake']", 'length': 3, 'lift': 1.146, 'confidence': 0.825, 'support': 0.241}
# {'rule': "['beef', 'vegetables']-->['bread and cake']", 'length': 3, 'lift': 1.146, 'confidence': 0.825, 'support': 0.23}
# {'rule': "['biscuits', 'breakfast food']-->['bread and cake']", 'length': 3, 'lift': 1.146, 'confidence': 0.825, 'support': 0.22}
# {'rule': "['fruit', 'wrapping']-->['bread and cake']", 'length': 3, 'lift': 1.146, 'confidence': 0.825, 'support': 0.166}
# {'rule': "['breakfast food', 'vegetables']-->['bread and cake']", 'length': 3, 'lift': 1.145, 'confidence': 0.824, 'support': 0.227}
# {'rule': "['cheese', 'frozen foods']-->['bread and cake']", 'length': 3, 'lift': 1.145, 'confidence': 0.824, 'support': 0.221}
# {'rule': "['dairy foods', 'frozen foods']-->['bread and cake']", 'length': 3, 'lift': 1.145, 'confidence': 0.824, 'support': 0.197}
# {'rule': "['department137', 'sauces-gravy-pkle']-->['bread and cake']", 'length': 3, 'lift': 1.144, 'confidence': 0.824, 'support': 0.172}
# {'rule': "['baking needs', 'fruit']-->['bread and cake']", 'length': 3, 'lift': 1.144, 'confidence': 0.823, 'support': 0.338}
# {'rule': "['frozen foods', 'tissues-paper prd']-->['bread and cake']", 'length': 3, 'lift': 1.144, 'confidence': 0.823, 'support': 0.268}
# {'rule': "['breakfast food', 'pet foods']-->['bread and cake']", 'length': 3, 'lift': 1.144, 'confidence': 0.823, 'support': 0.154}
# {'rule': "['frozen foods', 'vegetables']-->['bread and cake']", 'length': 3, 'lift': 1.143, 'confidence': 0.823, 'support': 0.335}
# {'rule': "['baking needs', 'tissues-paper prd']-->['bread and cake']", 'length': 3, 'lift': 1.143, 'confidence': 0.823, 'support': 0.28}
# {'rule': "['fruit', 'sauces-gravy-pkle']-->['bread and cake']", 'length': 3, 'lift': 1.143, 'confidence': 0.823, 'support': 0.265}
# {'rule': "['baking needs', 'laundry needs']-->['bread and cake']", 'length': 3, 'lift': 1.143, 'confidence': 0.822, 'support': 0.195}
# {'rule': "['beef', 'frozen foods']-->['bread and cake']", 'length': 3, 'lift': 1.142, 'confidence': 0.822, 'support': 0.212}
# {'rule': "['laundry needs', 'tissues-paper prd']-->['bread and cake']", 'length': 3, 'lift': 1.142, 'confidence': 0.822, 'support': 0.182}
# {'rule': "['frozen foods', 'wrapping']-->['bread and cake']", 'length': 3, 'lift': 1.142, 'confidence': 0.822, 'support': 0.164}
# {'rule': "['frozen foods', 'prepared meals']-->['bread and cake']", 'length': 3, 'lift': 1.141, 'confidence': 0.822, 'support': 0.165}
# {'rule': "['dairy foods', 'vegetables']-->['bread and cake']", 'length': 3, 'lift': 1.141, 'confidence': 0.821, 'support': 0.209}
# {'rule': "['baking needs', 'stationary']-->['bread and cake']", 'length': 3, 'lift': 1.141, 'confidence': 0.821, 'support': 0.163}
# {'rule': "['biscuits', 'stationary']-->['bread and cake']", 'length': 3, 'lift': 1.141, 'confidence': 0.821, 'support': 0.159}
# {'rule': "['breakfast food', 'fruit']-->['bread and cake']", 'length': 3, 'lift': 1.14, 'confidence': 0.821, 'support': 0.231}
# {'rule': "['party snack foods', 'tissues-paper prd']-->['bread and cake']", 'length': 3, 'lift': 1.14, 'confidence': 0.821, 'support': 0.231}
# {'rule': "['baking needs', 'department137']-->['bread and cake']", 'length': 3, 'lift': 1.14, 'confidence': 0.821, 'support': 0.215}
# {'rule': "['canned vegetables', 'sauces-gravy-pkle']-->['bread and cake']", 'length': 3, 'lift': 1.14, 'confidence': 0.821, 'support': 0.173}
# {'rule': "['biscuits', 'party snack foods']-->['bread and cake']", 'length': 3, 'lift': 1.14, 'confidence': 0.82, 'support': 0.282}
# {'rule': "['beef', 'margarine']-->['bread and cake']", 'length': 3, 'lift': 1.14, 'confidence': 0.82, 'support': 0.175}
# {'rule': "['baking needs', 'party snack foods']-->['bread and cake']", 'length': 3, 'lift': 1.139, 'confidence': 0.82, 'support': 0.271}
# {'rule': "['department137', 'vegetables']-->['bread and cake']", 'length': 3, 'lift': 1.139, 'confidence': 0.819, 'support': 0.23}
# {'rule': "['milk-cream', 'vegetables']-->['bread and cake']", 'length': 3, 'lift': 1.138, 'confidence': 0.819, 'support': 0.358}
# {'rule': "['laundry needs', 'sauces-gravy-pkle']-->['bread and cake']", 'length': 3, 'lift': 1.138, 'confidence': 0.819, 'support': 0.165}
# {'rule': "['frozen foods', 'stationary']-->['bread and cake']", 'length': 3, 'lift': 1.138, 'confidence': 0.819, 'support': 0.158}
# {'rule': "['cleaners-polishers', 'vegetables']-->['bread and cake']", 'length': 3, 'lift': 1.138, 'confidence': 0.819, 'support': 0.156}
# {'rule': "['dairy foods', 'fruit']-->['bread and cake']", 'length': 3, 'lift': 1.137, 'confidence': 0.819, 'support': 0.214}
# {'rule': "['tissues-paper prd', 'wrapping']-->['bread and cake']", 'length': 3, 'lift': 1.137, 'confidence': 0.819, 'support': 0.154}
# {'rule': "['margarine', 'sauces-gravy-pkle']-->['bread and cake']", 'length': 3, 'lift': 1.137, 'confidence': 0.818, 'support': 0.223}
# {'rule': "['department137', 'frozen foods']-->['bread and cake']", 'length': 3, 'lift': 1.137, 'confidence': 0.818, 'support': 0.211}
# {'rule': "['canned vegetables', 'margarine']-->['bread and cake']", 'length': 3, 'lift': 1.137, 'confidence': 0.818, 'support': 0.174}
# {'rule': "['milk-cream', 'sauces-gravy-pkle']-->['bread and cake']", 'length': 3, 'lift': 1.136, 'confidence': 0.818, 'support': 0.263}
# {'rule': "['confectionary', 'milk-cream']-->['bread and cake']", 'length': 3, 'lift': 1.136, 'confidence': 0.818, 'support': 0.204}
# {'rule': "['baking needs', 'jams-spreads']-->['bread and cake']", 'length': 3, 'lift': 1.136, 'confidence': 0.817, 'support': 0.165}
# {'rule': "['cheese', 'department137']-->['bread and cake']", 'length': 3, 'lift': 1.136, 'confidence': 0.817, 'support': 0.155}
# {'rule': "['party snack foods', 'vegetables']-->['bread and cake']", 'length': 3, 'lift': 1.135, 'confidence': 0.817, 'support': 0.275}
# {'rule': "['biscuits', 'sauces-gravy-pkle']-->['bread and cake']", 'length': 3, 'lift': 1.135, 'confidence': 0.817, 'support': 0.248}
# {'rule': "['breakfast food', 'margarine']-->['bread and cake']", 'length': 3, 'lift': 1.135, 'confidence': 0.817, 'support': 0.195}
# {'rule': "['dairy foods', 'sauces-gravy-pkle']-->['bread and cake']", 'length': 3, 'lift': 1.135, 'confidence': 0.817, 'support': 0.163}
# {'rule': "['biscuits', 'juice-sat-cord-ms']-->['bread and cake']", 'length': 3, 'lift': 1.134, 'confidence': 0.816, 'support': 0.272}
# {'rule': "['frozen foods', 'margarine']-->['bread and cake']", 'length': 3, 'lift': 1.134, 'confidence': 0.816, 'support': 0.27}
# {'rule': "['baking needs', 'cheese']-->['bread and cake']", 'length': 3, 'lift': 1.134, 'confidence': 0.816, 'support': 0.232}
# {'rule': "['stationary', 'vegetables']-->['bread and cake']", 'length': 3, 'lift': 1.133, 'confidence': 0.816, 'support': 0.17}
# {'rule': "['juice-sat-cord-ms', 'milk-cream']-->['bread and cake']", 'length': 3, 'lift': 1.132, 'confidence': 0.815, 'support': 0.288}
# {'rule': "['biscuits', 'confectionary']-->['bread and cake']", 'length': 3, 'lift': 1.132, 'confidence': 0.815, 'support': 0.199}
# {'rule': "['juice-sat-cord-ms', 'pet foods']-->['bread and cake']", 'length': 3, 'lift': 1.132, 'confidence': 0.815, 'support': 0.194}
# {'rule': "['beef', 'juice-sat-cord-ms']-->['bread and cake']", 'length': 3, 'lift': 1.132, 'confidence': 0.815, 'support': 0.172}
# {'rule': "['baking needs', 'vegetables']-->['bread and cake']", 'length': 3, 'lift': 1.131, 'confidence': 0.814, 'support': 0.343}
# {'rule': "['sauces-gravy-pkle', 'vegetables']-->['bread and cake']", 'length': 3, 'lift': 1.131, 'confidence': 0.814, 'support': 0.274}
# {'rule': "['milk-cream', 'stationary']-->['bread and cake']", 'length': 3, 'lift': 1.131, 'confidence': 0.814, 'support': 0.174}
# {'rule': "['frozen foods', 'laundry needs']-->['bread and cake']", 'length': 3, 'lift': 1.13, 'confidence': 0.814, 'support': 0.187}
# {'rule': "['cheese', 'sauces-gravy-pkle']-->['bread and cake']", 'length': 3, 'lift': 1.13, 'confidence': 0.813, 'support': 0.19}
# {'rule': "['dairy foods', 'juice-sat-cord-ms']-->['bread and cake']", 'length': 3, 'lift': 1.129, 'confidence': 0.813, 'support': 0.177}
# {'rule': "['breakfast food', 'cheese']-->['bread and cake']", 'length': 3, 'lift': 1.129, 'confidence': 0.813, 'support': 0.16}
# {'rule': "['milk-cream', 'soft drinks']-->['bread and cake']", 'length': 3, 'lift': 1.129, 'confidence': 0.812, 'support': 0.224}
# {'rule': "['biscuits', 'soft drinks']-->['bread and cake']", 'length': 3, 'lift': 1.129, 'confidence': 0.812, 'support': 0.209}
# {'rule': "['confectionary', 'fruit']-->['bread and cake']", 'length': 3, 'lift': 1.129, 'confidence': 0.812, 'support': 0.202}
# {'rule': "['baking needs', 'wrapping']-->['bread and cake']", 'length': 3, 'lift': 1.129, 'confidence': 0.812, 'support': 0.171}
# {'rule': "['fruit', 'vegetables']-->['bread and cake']", 'length': 3, 'lift': 1.128, 'confidence': 0.812, 'support': 0.387}
# {'rule': "['breakfast food', 'party snack foods']-->['bread and cake']", 'length': 3, 'lift': 1.128, 'confidence': 0.812, 'support': 0.192}
# {'rule': "['fruit', 'juice-sat-cord-ms']-->['bread and cake']", 'length': 3, 'lift': 1.127, 'confidence': 0.811, 'support': 0.293}
# {'rule': "['frozen foods', 'party snack foods']-->['bread and cake']", 'length': 3, 'lift': 1.127, 'confidence': 0.811, 'support': 0.277}
# {'rule': "['frozen foods', 'sauces-gravy-pkle']-->['bread and cake']", 'length': 3, 'lift': 1.127, 'confidence': 0.811, 'support': 0.262}
# {'rule': "['juice-sat-cord-ms', 'tissues-paper prd']-->['bread and cake']", 'length': 3, 'lift': 1.126, 'confidence': 0.81, 'support': 0.237}
# {'rule': "['sauces-gravy-pkle', 'tissues-paper prd']-->['bread and cake']", 'length': 3, 'lift': 1.126, 'confidence': 0.81, 'support': 0.226}
# {'rule': "['fruit', 'soft drinks']-->['bread and cake']", 'length': 3, 'lift': 1.126, 'confidence': 0.81, 'support': 0.222}
# {'rule': "['party snack foods', 'sauces-gravy-pkle']-->['bread and cake']", 'length': 3, 'lift': 1.125, 'confidence': 0.809, 'support': 0.23}
# {'rule': "['baking needs', 'frozen foods']-->['bread and cake']", 'length': 3, 'lift': 1.124, 'confidence': 0.809, 'support': 0.321}
# {'rule': "['soft drinks', 'tissues-paper prd']-->['bread and cake']", 'length': 3, 'lift': 1.124, 'confidence': 0.809, 'support': 0.177}
# {'rule': "['confectionary', 'vegetables']-->['bread and cake']", 'length': 3, 'lift': 1.123, 'confidence': 0.809, 'support': 0.193}
# {'rule': "['breakfast food', 'tissues-paper prd']-->['bread and cake']", 'length': 3, 'lift': 1.123, 'confidence': 0.808, 'support': 0.191}
# {'rule': "['department137', 'party snack foods']-->['bread and cake']", 'length': 3, 'lift': 1.123, 'confidence': 0.808, 'support': 0.184}
# {'rule': "['canned vegetables', 'juice-sat-cord-ms']-->['bread and cake']", 'length': 3, 'lift': 1.123, 'confidence': 0.808, 'support': 0.169}
# {'rule': "['juice-sat-cord-ms', 'margarine']-->['bread and cake']", 'length': 3, 'lift': 1.122, 'confidence': 0.808, 'support': 0.238}
# {'rule': "['dairy foods', 'party snack foods']-->['bread and cake']", 'length': 3, 'lift': 1.122, 'confidence': 0.807, 'support': 0.182}
# {'rule': "['margarine', 'soft drinks']-->['bread and cake']", 'length': 3, 'lift': 1.121, 'confidence': 0.807, 'support': 0.174}
# {'rule': "['baking needs', 'cleaners-polishers']-->['bread and cake']", 'length': 3, 'lift': 1.121, 'confidence': 0.807, 'support': 0.157}
# {'rule': "['cheese', 'juice-sat-cord-ms']-->['bread and cake']", 'length': 3, 'lift': 1.12, 'confidence': 0.806, 'support': 0.2}
# {'rule': "['baking needs', 'breakfast food']-->['bread and cake']", 'length': 3, 'lift': 1.118, 'confidence': 0.804, 'support': 0.232}
# {'rule': "['baking needs', 'sauces-gravy-pkle']-->['bread and cake']", 'length': 3, 'lift': 1.117, 'confidence': 0.804, 'support': 0.264}
# {'rule': "['department137', 'juice-sat-cord-ms']-->['bread and cake']", 'length': 3, 'lift': 1.117, 'confidence': 0.804, 'support': 0.182}
# {'rule': "['breakfast food', 'frozen foods']-->['bread and cake']", 'length': 3, 'lift': 1.116, 'confidence': 0.803, 'support': 0.219}
# {'rule': "['fruit', 'stationary']-->['bread and cake']", 'length': 3, 'lift': 1.116, 'confidence': 0.803, 'support': 0.174}
# {'rule': "['laundry needs', 'margarine']-->['bread and cake']", 'length': 3, 'lift': 1.116, 'confidence': 0.803, 'support': 0.172}
# {'rule': "['frozen foods', 'soft drinks']-->['bread and cake']", 'length': 3, 'lift': 1.115, 'confidence': 0.802, 'support': 0.219}
# {'rule': "['baking needs', 'confectionary']-->['bread and cake']", 'length': 3, 'lift': 1.115, 'confidence': 0.802, 'support': 0.19}
# {'rule': "['confectionary', 'frozen foods']-->['bread and cake']", 'length': 3, 'lift': 1.114, 'confidence': 0.802, 'support': 0.188}
# {'rule': "['confectionary', 'party snack foods']-->['bread and cake']", 'length': 3, 'lift': 1.114, 'confidence': 0.802, 'support': 0.177}
# {'rule': "['small goods']-->['bread and cake']", 'length': 2, 'lift': 1.16, 'confidence': 0.835, 'support': 0.201}
# {'rule': "['canned fruit']-->['bread and cake']", 'length': 2, 'lift': 1.126, 'confidence': 0.811, 'support': 0.225}
# {'rule': "['jams-spreads']-->['bread and cake']", 'length': 2, 'lift': 1.117, 'confidence': 0.804, 'support': 0.222}
# {'rule': "['canned fish-meat']-->['bread and cake']", 'length': 2, 'lift': 1.113, 'confidence': 0.801, 'support': 0.163}
# {'rule': "['margarine']-->['bread and cake']", 'length': 2, 'lift': 1.112, 'confidence': 0.8, 'support': 0.396}
